# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer
from tensorflow.keras.layers import (Reshape, Conv2DTranspose, Add, Conv2D, MaxPool2D, Dense,
                                     Flatten, InputLayer, BatchNormalization, Input, )
from tensorflow.keras.optimizers import Adam
# Out:
# 2024-07-22 23:34:09.130295: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-22 23:34:09.130355: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-22 23:34:09.131536: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-22 23:34:09.138802: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-22 23:34:10.393876: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data loading

# %%
(x_train, _), (x_test, _) = tf.keras.datasets.mnist.load_data()
mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

# %%
dataset = tf.data.Dataset.from_tensor_slices(mnist_digits)
# Out:
# 2024-07-22 23:34:13.079681: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-22 23:34:13.125090: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-22 23:34:13.125167: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-22 23:34:13.129667: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-22 23:34:13.129739: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-22 23:34:13.129823: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-22 23:34:13.306857: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-22 23:34:13.306963: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-22 23:34:13.306979: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-07-22 23:34:13.307041: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-22 23:34:13.307064: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3586 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
len(dataset)
# Out:
# 70000

# %%
batch_size = 128

# %%
train_dataset = (
    dataset
    .shuffle(buffer_size = 1024, reshuffle_each_iteration = True)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

# %%
train_dataset
# Out:
# <_PrefetchDataset element_spec=TensorSpec(shape=(None, 28, 28, 1), dtype=tf.float32, name=None)>

# %% [markdown]
# ## Modeling

# %%
latent_dim = 2

# %%
class Sampling(Layer):
  def call(self, inputs):
    mean, log_var = inputs
    return mean + tf.math.exp(0.5*log_var)*tf.random.normal(shape = (tf.shape(mean)[0], tf.shape(mean)[1]))

# %% [markdown]
# ### Encoder

# %%
encoder_inputs = Input(shape=(28,28,1))

x = Conv2D(32, 3, activation='relu', strides=2, padding='same')(encoder_inputs)
x = Conv2D(64, 3, activation='relu', strides=2, padding='same')(x)

x = Flatten()(x)
x = Dense(16, activation='relu')(x)

mean = Dense(latent_dim,)(x)
log_var = Dense(latent_dim ,)(x)

z = Sampling()([mean,log_var])

encoder_model = Model(encoder_inputs,[z,mean,log_var], name='encoder')
encoder_model.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 14, 14, 32)           320       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)             18496     ['conv2d[0][0]']
#
#  flatten (Flatten)           (None, 3136)                 0         ['conv2d_1[0][0]']
#
#  dense (Dense)               (None, 16)                   50192     ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 2)                    34        ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 2)                    34        ['dense[0][0]']
#
#  sampling (Sampling)         (None, 2)                    0         ['dense_1[0][0]',
#                                                                      'dense_2[0][0]']
#
# ==================================================================================================
# Total params: 69076 (269.83 KB)
# Trainable params: 69076 (269.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Decoder

# %%
latent_inputs = Input(shape=(latent_dim,))


x = Dense(7*7*64, activation='relu')(latent_inputs)
x = Reshape((7,7,64))(x)

x = Conv2DTranspose(64, 3, activation='relu', strides=2, padding='same')(x)
x = Conv2DTranspose(32, 3, activation='relu', strides=2, padding='same')(x)

decoder_output = Conv2DTranspose(1, 3, activation='sigmoid', padding='same')(x)
decoder_model = Model(latent_inputs,decoder_output,name='decoder')
decoder_model.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_3 (Dense)             (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTr  (None, 14, 14, 64)        36928
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 28, 28, 32)        18464
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 1)         289
#  Transpose)
#
# =================================================================
# Total params: 65089 (254.25 KB)
# Trainable params: 65089 (254.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
vae_input = Input(shape=(28,28,1), name="vae_input")
z,_,_ = encoder_model(vae_input)
output = decoder_model(z)
vae = Model(vae_input, output, name="vae")
vae.summary()
# Out:
# Model: "vae"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vae_input (InputLayer)      [(None, 28, 28, 1)]       0
#
#  encoder (Functional)        [(None, 2),               69076
#                               (None, 2),
#                               (None, 2)]
#
#  decoder (Functional)        (None, 28, 28, 1)         65089
#
# =================================================================
# Total params: 134165 (524.08 KB)
# Trainable params: 134165 (524.08 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
OPTIMIZER = Adam(learning_rate = 1e-3)
EPOCHS = 100

# %%
def custom_loss(y_true,y_pred,mean,log_var):

  loss_rec = tf.reduce_mean(tf.reduce_sum(tf.keras.losses.binary_crossentropy(y_true,y_pred), axis = (1,2)))

  loss_reg = -0.5 * (1 + log_var - tf.square(mean) - tf.exp(log_var))
  
  return loss_rec+tf.reduce_mean(tf.reduce_sum(loss_reg, axis=1))

# %%
@tf.function
def training_block(x_batch):
  with tf.GradientTape() as recorder:
    z,mean,log_var = encoder_model(x_batch)
    y_pred = decoder_model(z)
    y_true = x_batch
    loss = custom_loss(y_true,y_pred, mean, log_var)
  
  partial_derivatives = recorder.gradient(loss,vae.trainable_weights)
  OPTIMIZER.apply_gradients(zip(partial_derivatives, vae.trainable_weights))
  return loss

# %%
def trainer(epochs):
  for epoch in range(1,epochs+1):
    print('Training starts for epoch number {}'.format(epoch))

    for step, x_batch in enumerate(train_dataset):
      loss = training_block(x_batch)
    print('Training Loss is: ', loss)
  print('Training Complete!!!')

# %%
trainer(EPOCHS)
# Out:
# Training starts for epoch number 1
# 2024-07-22 23:34:15.372633: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# 2024-07-22 23:34:15.535336: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-07-22 23:34:15.786423: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-07-22 23:34:16.884039: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fb18bcfeb70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-22 23:34:16.884099: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2024-07-22 23:34:16.890390: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721671456.975617   84799 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Training Loss is:  tf.Tensor(189.00768, shape=(), dtype=float32)
# Training starts for epoch number 2
# Training Loss is:  tf.Tensor(172.22871, shape=(), dtype=float32)
# Training starts for epoch number 3
# Training Loss is:  tf.Tensor(164.18353, shape=(), dtype=float32)
# Training starts for epoch number 4
# Training Loss is:  tf.Tensor(161.35793, shape=(), dtype=float32)
# Training starts for epoch number 5
# Training Loss is:  tf.Tensor(156.35294, shape=(), dtype=float32)
# Training starts for epoch number 6
# Training Loss is:  tf.Tensor(153.15384, shape=(), dtype=float32)
# Training starts for epoch number 7
# Training Loss is:  tf.Tensor(155.41174, shape=(), dtype=float32)
# Training starts for epoch number 8
# Training Loss is:  tf.Tensor(156.32549, shape=(), dtype=float32)
# Training starts for epoch number 9
# Training Loss is:  tf.Tensor(158.9407, shape=(), dtype=float32)
# Training starts for epoch number 10
# Training Loss is:  tf.Tensor(153.7763, shape=(), dtype=float32)
# Training starts for epoch number 11
# Training Loss is:  tf.Tensor(151.3179, shape=(), dtype=float32)
# Training starts for epoch number 12
# Training Loss is:  tf.Tensor(152.57765, shape=(), dtype=float32)
# Training starts for epoch number 13
# Training Loss is:  tf.Tensor(153.17749, shape=(), dtype=float32)
# Training starts for epoch number 14
# Training Loss is:  tf.Tensor(148.52487, shape=(), dtype=float32)
# Training starts for epoch number 15
# Training Loss is:  tf.Tensor(157.2761, shape=(), dtype=float32)
# Training starts for epoch number 16
# Training Loss is:  tf.Tensor(153.42316, shape=(), dtype=float32)
# Training starts for epoch number 17
# Training Loss is:  tf.Tensor(150.21312, shape=(), dtype=float32)
# Training starts for epoch number 18
# Training Loss is:  tf.Tensor(139.76987, shape=(), dtype=float32)
# Training starts for epoch number 19
# Training Loss is:  tf.Tensor(153.06914, shape=(), dtype=float32)
# Training starts for epoch number 20
# Training Loss is:  tf.Tensor(141.24034, shape=(), dtype=float32)
# Training starts for epoch number 21
# Training Loss is:  tf.Tensor(162.97786, shape=(), dtype=float32)
# Training starts for epoch number 22
# Training Loss is:  tf.Tensor(145.35165, shape=(), dtype=float32)
# Training starts for epoch number 23
# Training Loss is:  tf.Tensor(154.1855, shape=(), dtype=float32)
# Training starts for epoch number 24
# Training Loss is:  tf.Tensor(147.53532, shape=(), dtype=float32)
# Training starts for epoch number 25
# Training Loss is:  tf.Tensor(137.81317, shape=(), dtype=float32)
# Training starts for epoch number 26
# Training Loss is:  tf.Tensor(147.12842, shape=(), dtype=float32)
# Training starts for epoch number 27
# Training Loss is:  tf.Tensor(146.04448, shape=(), dtype=float32)
# Training starts for epoch number 28
# Training Loss is:  tf.Tensor(140.5301, shape=(), dtype=float32)
# Training starts for epoch number 29
# Training Loss is:  tf.Tensor(152.66934, shape=(), dtype=float32)
# Training starts for epoch number 30
# Training Loss is:  tf.Tensor(144.31113, shape=(), dtype=float32)
# Training starts for epoch number 31
# Training Loss is:  tf.Tensor(145.10852, shape=(), dtype=float32)
# Training starts for epoch number 32
# Training Loss is:  tf.Tensor(142.07893, shape=(), dtype=float32)
# Training starts for epoch number 33
# Training Loss is:  tf.Tensor(144.71237, shape=(), dtype=float32)
# Training starts for epoch number 34
# Training Loss is:  tf.Tensor(146.7862, shape=(), dtype=float32)
# Training starts for epoch number 35
# Training Loss is:  tf.Tensor(145.26025, shape=(), dtype=float32)
# Training starts for epoch number 36
# Training Loss is:  tf.Tensor(137.8124, shape=(), dtype=float32)
# Training starts for epoch number 37
# Training Loss is:  tf.Tensor(140.59125, shape=(), dtype=float32)
# Training starts for epoch number 38
# Training Loss is:  tf.Tensor(137.94101, shape=(), dtype=float32)
# Training starts for epoch number 39
# Training Loss is:  tf.Tensor(139.81926, shape=(), dtype=float32)
# Training starts for epoch number 40
# Training Loss is:  tf.Tensor(146.6201, shape=(), dtype=float32)
# Training starts for epoch number 41
# Training Loss is:  tf.Tensor(146.55533, shape=(), dtype=float32)
# Training starts for epoch number 42
# Training Loss is:  tf.Tensor(147.49876, shape=(), dtype=float32)
# Training starts for epoch number 43
# Training Loss is:  tf.Tensor(139.12079, shape=(), dtype=float32)
# Training starts for epoch number 44
# Training Loss is:  tf.Tensor(143.72101, shape=(), dtype=float32)
# Training starts for epoch number 45
# Training Loss is:  tf.Tensor(147.29404, shape=(), dtype=float32)
# Training starts for epoch number 46
# Training Loss is:  tf.Tensor(144.5886, shape=(), dtype=float32)
# Training starts for epoch number 47
# Training Loss is:  tf.Tensor(143.95695, shape=(), dtype=float32)
# Training starts for epoch number 48
# Training Loss is:  tf.Tensor(148.97487, shape=(), dtype=float32)
# Training starts for epoch number 49
# Training Loss is:  tf.Tensor(142.47736, shape=(), dtype=float32)
# Training starts for epoch number 50
# Training Loss is:  tf.Tensor(143.19945, shape=(), dtype=float32)
# Training starts for epoch number 51
# Training Loss is:  tf.Tensor(143.35345, shape=(), dtype=float32)
# Training starts for epoch number 52
# Training Loss is:  tf.Tensor(137.54501, shape=(), dtype=float32)
# Training starts for epoch number 53
# Training Loss is:  tf.Tensor(139.55023, shape=(), dtype=float32)
# Training starts for epoch number 54
# Training Loss is:  tf.Tensor(140.26091, shape=(), dtype=float32)
# Training starts for epoch number 55
# Training Loss is:  tf.Tensor(140.45512, shape=(), dtype=float32)
# Training starts for epoch number 56
# Training Loss is:  tf.Tensor(141.63342, shape=(), dtype=float32)
# Training starts for epoch number 57
# Training Loss is:  tf.Tensor(147.80429, shape=(), dtype=float32)
# Training starts for epoch number 58
# Training Loss is:  tf.Tensor(145.33788, shape=(), dtype=float32)
# Training starts for epoch number 59
# Training Loss is:  tf.Tensor(145.17917, shape=(), dtype=float32)
# Training starts for epoch number 60
# Training Loss is:  tf.Tensor(148.41132, shape=(), dtype=float32)
# Training starts for epoch number 61
# Training Loss is:  tf.Tensor(146.86862, shape=(), dtype=float32)
# Training starts for epoch number 62
# Training Loss is:  tf.Tensor(138.75629, shape=(), dtype=float32)
# Training starts for epoch number 63
# Training Loss is:  tf.Tensor(146.68419, shape=(), dtype=float32)
# Training starts for epoch number 64
# Training Loss is:  tf.Tensor(141.73431, shape=(), dtype=float32)
# Training starts for epoch number 65
# Training Loss is:  tf.Tensor(140.64676, shape=(), dtype=float32)
# Training starts for epoch number 66
# Training Loss is:  tf.Tensor(142.47684, shape=(), dtype=float32)
# Training starts for epoch number 67
# Training Loss is:  tf.Tensor(150.51376, shape=(), dtype=float32)
# Training starts for epoch number 68
# Training Loss is:  tf.Tensor(141.72058, shape=(), dtype=float32)
# Training starts for epoch number 69
# Training Loss is:  tf.Tensor(139.0802, shape=(), dtype=float32)
# Training starts for epoch number 70
# Training Loss is:  tf.Tensor(140.7763, shape=(), dtype=float32)
# Training starts for epoch number 71
# Training Loss is:  tf.Tensor(144.76405, shape=(), dtype=float32)
# Training starts for epoch number 72
# Training Loss is:  tf.Tensor(141.65193, shape=(), dtype=float32)
# Training starts for epoch number 73
# Training Loss is:  tf.Tensor(145.10252, shape=(), dtype=float32)
# Training starts for epoch number 74
# Training Loss is:  tf.Tensor(146.48253, shape=(), dtype=float32)
# Training starts for epoch number 75
# Training Loss is:  tf.Tensor(138.46823, shape=(), dtype=float32)
# Training starts for epoch number 76
# Training Loss is:  tf.Tensor(141.85341, shape=(), dtype=float32)
# Training starts for epoch number 77
# Training Loss is:  tf.Tensor(139.04143, shape=(), dtype=float32)
# Training starts for epoch number 78
# Training Loss is:  tf.Tensor(137.35919, shape=(), dtype=float32)
# Training starts for epoch number 79
# Training Loss is:  tf.Tensor(144.59743, shape=(), dtype=float32)
# Training starts for epoch number 80
# Training Loss is:  tf.Tensor(146.71681, shape=(), dtype=float32)
# Training starts for epoch number 81
# Training Loss is:  tf.Tensor(144.31506, shape=(), dtype=float32)
# Training starts for epoch number 82
# Training Loss is:  tf.Tensor(140.15125, shape=(), dtype=float32)
# Training starts for epoch number 83
# Training Loss is:  tf.Tensor(148.91171, shape=(), dtype=float32)
# Training starts for epoch number 84
# Training Loss is:  tf.Tensor(138.93726, shape=(), dtype=float32)
# Training starts for epoch number 85
# Training Loss is:  tf.Tensor(141.40811, shape=(), dtype=float32)
# Training starts for epoch number 86
# Training Loss is:  tf.Tensor(138.51201, shape=(), dtype=float32)
# Training starts for epoch number 87
# Training Loss is:  tf.Tensor(150.92137, shape=(), dtype=float32)
# Training starts for epoch number 88
# Training Loss is:  tf.Tensor(142.35617, shape=(), dtype=float32)
# Training starts for epoch number 89
# Training Loss is:  tf.Tensor(145.85306, shape=(), dtype=float32)
# Training starts for epoch number 90
# Training Loss is:  tf.Tensor(138.973, shape=(), dtype=float32)
# Training starts for epoch number 91
# Training Loss is:  tf.Tensor(140.94638, shape=(), dtype=float32)
# Training starts for epoch number 92
# Training Loss is:  tf.Tensor(142.11505, shape=(), dtype=float32)
# Training starts for epoch number 93
# Training Loss is:  tf.Tensor(140.56198, shape=(), dtype=float32)
# Training starts for epoch number 94
# Training Loss is:  tf.Tensor(139.6942, shape=(), dtype=float32)
# Training starts for epoch number 95
# Training Loss is:  tf.Tensor(142.76158, shape=(), dtype=float32)
# Training starts for epoch number 96
# Training Loss is:  tf.Tensor(143.04312, shape=(), dtype=float32)
# Training starts for epoch number 97
# Training Loss is:  tf.Tensor(139.66968, shape=(), dtype=float32)
# Training starts for epoch number 98
# Training Loss is:  tf.Tensor(140.87163, shape=(), dtype=float32)
# Training starts for epoch number 99
# Training Loss is:  tf.Tensor(135.77312, shape=(), dtype=float32)
# Training starts for epoch number 100
# Training Loss is:  tf.Tensor(142.97166, shape=(), dtype=float32)
# Training Complete!!!

# %% [markdown]
# ## Testing

# %%
scale=1
n=16

# %%
grid_x = np.linspace(-scale,scale,16)
grid_y = np.linspace(-scale,scale,16)

# %%
plt.figure(figsize=(12,12))
k=0
for i in grid_x:
  for j in grid_y:
    ax=plt.subplot(n,n,k+1)

    input=tf.constant([[i,j]])
    out=vae.layers[2].predict(input)[0][...,0]
    plt.imshow(out,cmap="Greys_r")
    plt.axis('off')
    k+=1
# Out:
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
(x_train, y_train), _ = tf.keras.datasets.mnist.load_data()
mnist_digits = np.expand_dims(x_train,-1).astype("float32") / 255

# %%
z,_,_=vae.layers[1].predict(x_train)
plt.figure(figsize=(12,12))
plt.scatter(z[:,0],z[:,1],c=y_train)
plt.colorbar()
plt.show()
# Out:
# 1875/1875 [==============================] - 4s 2ms/step

# %% [markdown]
# ## Overriding train_step

# %%
class VAE(tf.keras.Model):
  def __init__(self,encoder_model, decoder_model):
    super(VAE,self).__init__()
    self.encoder=encoder_model
    self.decoder=decoder_model
    self.loss_tracker=tf.keras.metrics.Mean(name='loss')
  @property
  def metrics(self):
    return [self.loss_tracker]
  
  def train_step(self,x_batch):
    with tf.GradientTape() as recorder:
      z,mean,log_var = encoder_model(x_batch)
      y_pred = decoder_model(z)
      y_true = x_batch
      loss = custom_loss(y_true,y_pred, mean, log_var)
    
    partial_derivatives = recorder.gradient(loss,self.trainable_weights)
    OPTIMIZER.apply_gradients(zip(partial_derivatives, self.trainable_weights))

    self.loss_tracker.update_state(loss)
    return {'loss':self.loss_tracker.result()}

# %%
model=VAE(encoder_model,decoder_model)
model.compile(optimizer=OPTIMIZER)
model.fit(train_dataset, epochs=20,batch_size=128,)
# Out:
# Epoch 1/20
# 547/547 [==============================] - 10s 14ms/step - loss: 144.4976
# Epoch 2/20
# 547/547 [==============================] - 7s 14ms/step - loss: 144.5484
# Epoch 3/20
# 547/547 [==============================] - 7s 13ms/step - loss: 144.3963
# Epoch 4/20
# 547/547 [==============================] - 7s 14ms/step - loss: 144.4698
# Epoch 5/20
# 547/547 [==============================] - 7s 13ms/step - loss: 144.4379
# Epoch 6/20
# 547/547 [==============================] - 7s 12ms/step - loss: 144.4592
# Epoch 7/20
# 547/547 [==============================] - 7s 12ms/step - loss: 144.3291
# Epoch 8/20
# 547/547 [==============================] - 7s 13ms/step - loss: 144.2894
# Epoch 9/20
# 547/547 [==============================] - 7s 13ms/step - loss: 144.3338
# Epoch 10/20
# 547/547 [==============================] - 7s 13ms/step - loss: 144.3032
# Epoch 11/20
# 547/547 [==============================] - 7s 13ms/step - loss: 144.3262
# Epoch 12/20
# 547/547 [==============================] - 8s 14ms/step - loss: 144.3162
# Epoch 13/20
# 547/547 [==============================] - 7s 12ms/step - loss: 144.2608
# Epoch 14/20
# 547/547 [==============================] - 6s 12ms/step - loss: 144.1853
# Epoch 15/20
# 547/547 [==============================] - 7s 13ms/step - loss: 144.2150
# Epoch 16/20
# 547/547 [==============================] - 7s 13ms/step - loss: 144.2319
# Epoch 17/20
# 547/547 [==============================] - 7s 14ms/step - loss: 144.1184
# Epoch 18/20
# 547/547 [==============================] - 7s 14ms/step - loss: 144.1320
# Epoch 19/20
# 547/547 [==============================] - 7s 13ms/step - loss: 144.0482
# Epoch 20/20
# 547/547 [==============================] - 7s 13ms/step - loss: 144.1373

# %%
plt.figure(figsize=(12,12))
k=0
for i in grid_x:
  for j in grid_y:
    ax=plt.subplot(n,n,k+1)

    input=tf.constant([[i,j]])
    #Accomodating the change in model building
    out=model.decoder.predict(input)[0][...,0]
    plt.imshow(out,cmap="Greys_r")
    plt.axis('off')
    k+=1
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
